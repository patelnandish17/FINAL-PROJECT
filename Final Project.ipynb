# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
file_path = "netflix_movies_detailed_up_to_2025.csv"
data = pd.read_csv(file_path)

# Display basic info and first rows
print(data.info())
print(data.head())

# Top 10 genres
all_genres = data['genres'].dropna().str.split(', ').sum()
top_genres = pd.Series(all_genres).value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_genres.values, y=top_genres.index, palette='magma')
plt.title('Top 10 Most Common Genres on Netflix')
plt.xlabel('Count')
plt.show()

# Release year trend
plt.figure(figsize=(10, 6))
sns.histplot(data['release_year'], bins=30, kde=True, color='skyblue')
plt.title('Number of Releases Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.show()

# Ratings distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['rating'], bins=20, kde=True, color='lightcoral')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# Budget vs Revenue scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='budget', y='revenue', hue='type', alpha=0.7)
plt.title('Budget vs Revenue (Movies & TV Shows)')
plt.xlabel('Budget ($)')
plt.ylabel('Revenue ($)')
plt.legend(title='Type')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      15868 non-null  object
#  4   cast          15796 non-null  object
#  5   country       15534 non-null  object
#  6   date_added    16000 non-null  object
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   Unnamed: 9    0 non-null      float64
#  10  genres        15893 non-null  object
#  11  language      16000 non-null  object
#  12  description   15868 non-null  object
#  13  popularity    16000 non-null  float64
#  14  vote_count    16000 non-null  int64
#  15  vote_average  16000 non-null  float64
#  16  budget        16000 non-null  int64
#  17  revenue       16000 non-null  int64
# ...

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-35db8ad1-12db-4491-9cac-54677fb5e493" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35db8ad1-12db-4491-9cac-54677fb5e493">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
